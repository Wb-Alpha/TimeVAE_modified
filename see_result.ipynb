# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
prior = np.load(r'C:\Users\ASUS\Desktop\timeVAE-main\src\decoded_samples.npy')

# %%
plt.plot(prior.reshape(-1,1440,6)[0,:,1][:1400])

# %%
plt.plot(prior[1])

# %%
dataset = np.load(r"C:\Users\ASUS\Desktop\final_trial\data\few_train_set.npy")

# %%
appliance_id = [0,1,2,3,6,7]

# %%
dataset[:,:,appliance_id]
# Out:
# array([[[1.667780e+02, 0.000000e+00, 1.000000e+00, 1.000000e+00,
#          0.000000e+00, 0.000000e+00],
#         [1.674000e+02, 0.000000e+00, 1.000000e+00, 1.000000e+00,
#          0.000000e+00, 0.000000e+00],
#         [1.682000e+02, 0.000000e+00, 1.000000e+00, 1.000000e+00,
#          0.000000e+00, 0.000000e+00],
#         ...,
#         [2.161000e+02, 0.000000e+00, 1.000000e+00, 1.000000e+00,
#          0.000000e+00, 6.470000e+01],
#         [2.065000e+02, 0.000000e+00, 1.000000e+00, 1.000000e+00,
#          0.000000e+00, 5.700000e+01],
#         [2.188000e+02, 0.000000e+00, 1.000000e+00, 1.000000e+00,
#          0.000000e+00, 7.000000e+01]],
#
#        [[2.244000e+02, 0.000000e+00, 1.000000e+00, 1.000000e+00,
#          0.000000e+00, 7.222200e+01],
#         [2.166000e+02, 0.000000e+00, 1.000000e+00, 1.000000e+00,
#          0.000000e+00, 6.322200e+01],
#         [2.102000e+02, 0.000000e+00, 1.000000e+00, 1.000000e+00,
#          0.000000e+00, 5.687500e+01],
#         ...,
# ...

# %%
df = np.load(r"C:\Users\ASUS\Desktop\timeVAE-main\src\prior_samples.npy")

# %%
df.shape
# Out:
# (602, 1440, 1)

# %%
df = np.transpose(df,(0,2,1))

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)

plt.plot(np.transpose(df[9],(1,0)))
plt.subplot(1,2,2)
# plt.plot(df[10])
# Out:
# <AxesSubplot:>

# %%
 np.save("VAE_synthetic.npy",df)

# %%
data = np.load(r'C:\Users\ASUS\Desktop\NILM+VAE\preprocessing\dataset1440.npy')

# %%
data[0]
# Out:
# array([[0.025, 0.   , 0.   , 0.001, 0.   , 0.   ],
#        [0.025, 0.   , 0.   , 0.001, 0.   , 0.   ],
#        [0.024, 0.   , 0.   , 0.001, 0.   , 0.   ],
#        ...,
#        [0.028, 0.   , 0.   , 0.001, 0.   , 0.   ],
#        [0.027, 0.   , 0.   , 0.   , 0.   , 0.   ],
#        [0.027, 0.   , 0.   , 0.001, 0.   , 0.   ]], dtype=float32)

# %%
plt.plot(data[0])

# %%
x = np.load(r"C:\Users\ASUS\Desktop\timeVAE-main\src\prior_samples.npy")

# %%
np.load(r"C:\Users\ASUS\Desktop\timeVAE-main\src\variance.npy")
# Out:
# array([[-0.1392962 , -0.21981333, -0.13445592, ..., -3.4260762 ,
#         -3.0207875 , -0.23844044],
#        [-0.01445363, -0.01690156, -0.07253252, ..., -1.4226824 ,
#         -0.1078025 , -0.18215147],
#        [-0.02221122, -0.03577936, -0.08020315, ..., -1.793192  ,
#         -0.47235346, -0.20627192],
#        ...,
#        [ 0.0048151 , -0.02768973, -0.08246107, ..., -1.6136798 ,
#         -0.01412348, -0.2628643 ],
#        [-0.0213726 , -0.04020371, -0.08981375, ..., -1.5918447 ,
#         -0.02011807, -0.24421692],
#        [-0.04432591, -0.06550481, -0.11680212, ..., -1.5647248 ,
#         -0.09901687, -0.27606347]], dtype=float32)

# %%
plt.plot(x[2])

# %%
np.load()

# %%
training_data = np.load(r"folder\训练\kettle_training.npy")
generated_data =np.load(r'C:\Users\ASUS\Desktop\timeVAE-main\outputs\kettle_2000.npy')

# %%
generated_index = 1
training_index = 13
plt.grid("--")
plt.subplot(5,2,1)
plt.plot(generated_data[generated_index][:,0])
plt.subplot(5,2,3)
plt.plot(generated_data[generated_index][:,1])
plt.subplot(5,2,5)
plt.plot(generated_data[generated_index][:,2])
plt.subplot(5,2,7)
plt.plot(generated_data[generated_index][:,3])
plt.subplot(5,2,9)
plt.plot(generated_data[generated_index][:,4])

plt.subplot(5,2,2)
plt.plot(training_data[training_index][:,0])

plt.subplot(5,2,4)
plt.plot(training_data[training_index][:,1])

plt.subplot(5,2,6)
plt.plot(training_data[training_index][:,2])

plt.subplot(5,2,8)
plt.plot(training_data[training_index][:,3])

plt.subplot(5,2,10)
plt.plot(training_data[training_index][:,4])

plt.tight_layout()

# %%
len(np.load(r'C:\Users\ASUS\Desktop\timeVAE-main\outputs\kettle_2000.npy'))
# Out:
# 791

# %%
for i in range(30):
    plt.figure(figsize=(3,3))
    plt.plot(generated_data[i][:,0])
# Out:
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_17532/1206971239.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(3,3))

# %%
plt.subplot(5,2,2)
plt.plot(training_data[23][:,0])

# %%
for i in range(30):
    plt.figure(figsize=(3,3))
    plt.plot(training_data[i][:,0])
    plt.show()
